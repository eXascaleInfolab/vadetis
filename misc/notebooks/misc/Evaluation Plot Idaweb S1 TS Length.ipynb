# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# Results
dimension = np.array([200, 400, 600, 800, 1000])

# Results array [nmi, rmse, f1]

## LISA
lisa_pearson_results = np.array([[0.312, 0.016, 0.4], [0.752, 0.013, 0.894], [0.646, 0.015, 0.83], [0.697, 0.015, 0.829], [0.726, 0.013, 0.851]])
lisa_dtw_results = np.array([[0.312, 0.016, 0.4], [0.645, 0.02, 0.84], [0.609, 0.017, 0.792], [0.723, 0.013, 0.865], [0.721, 0.012, 0.872]])
lisa_spatial_results = np.array([[0.758, 0.005, 0.857], [0.94, 0.003, 0.98], [0.946, 0.002, 0.981], [0.895, 0.004, 0.964], [0.911, 0.003, 0.97]])

rpca_results = np.array([[0.001, 0.645, 0.044], [0.133, 0.253, 0.313], [0.623, 0.02, 0.806], [0.522, 0.037, 0.722], [0.756, 0.011, 0.895]])

histogram_results = np.array([[0.005, 0.95, 0.04], [0.017, 0.91, 0.108], [0.004, 0.903, 0.081], [0, 0.89, 0.096], [0.007, 0.801, 0.105]])

cluster_results = np.array([[0.008, 0.92, 0.042], [0.179, 0.215, 0.358], [0.468, 0.037, 0.686], [0.452, 0.048, 0.667], [0.679, 0.017, 0.847]])

svm_results = np.array([[0.095, 0.11, 0.214], [0.394, 0.077, 0.608], [0.343, 0.033, 0.583], [0.214, 0.07, 0.472], [0.11, 0.098, 0.338]])

isolation_results = np.array([[0.011, 0.425, 0.066], [0.225, 0.168, 0.417], [0.26, 0.062, 0.507], [0.144, 0.156, 0.346], [0, 0.155, 0.061]])

results_tpl = np.array([[], [], [], [], []])

# %%
scores = [{ 'title' : 'LISA (Pearson)', 'scores' : lisa_pearson_results }, 
          { 'title' : 'LISA (DTW)', 'scores' : lisa_dtw_results }, 
          { 'title' : 'LISA (Vanilla)', 'scores' :  lisa_spatial_results }, 
          { 'title' : 'RPCA', 'scores' :  rpca_results }, 
          { 'title' : 'Histogram', 'scores' :  histogram_results }, 
          { 'title' : 'Cluster', 'scores' :  cluster_results }, 
          { 'title' : 'SVM', 'scores' :  svm_results }, 
          { 'title' : 'Isolation Forest', 'scores' :  isolation_results }
         ]

# %%
def generate_nmi_line_chart(dimension, scores):
    fig, ax = plt.subplots()
    
    for score in scores:
        title = score['title']
        results = score['scores']
        ax.plot(dimension, results[:,0], label=title)
    ax.set_ylabel('Score')
    ax.set_xlabel('Length of TS')
    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left", borderaxespad=0, ncol=3)
    
    fig.tight_layout()
    plt.show()

# %%
def generate_rmse_line_chart(dimension, scores):
    fig, ax = plt.subplots()
    
    for score in scores:
        title = score['title']
        results = score['scores']
        ax.plot(dimension, results[:,1], label=title)
        #ax.plot(dimension, scores[:, 1], label='$RMSE$')
        #ax.plot(dimension, scores[:, 2], label='$F_1-Score$')
    ax.set_ylabel('Score')
    ax.set_xlabel('Length of TS')
    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left", borderaxespad=0, ncol=3)
    
    fig.tight_layout()
    plt.show()

# %%
def generate_f1_line_chart(dimension, scores):
    fig, ax = plt.subplots()
    
    for score in scores:
        title = score['title']
        results = score['scores']
        ax.plot(dimension, results[:,2], label=title)
    ax.set_ylabel('Score')
    ax.set_xlabel('Length of TS')
    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left", borderaxespad=0, ncol=3)
    
    fig.tight_layout()
    plt.show()

# %%
generate_nmi_line_chart(dimension, scores)

# %%
generate_rmse_line_chart(dimension, scores)

# %%
generate_f1_line_chart(dimension, scores)
