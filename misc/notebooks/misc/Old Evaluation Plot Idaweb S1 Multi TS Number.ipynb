# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# Results
dimension = np.array([4, 6, 8, 10, 12, 14])

# Results array [nmi, rmse, f1]

rpca_results = np.array([[0.607, 0.02, 0.75], [0.798, 0.009, 0.901], [0.59, 0.021, 0.734], [0.487, 0.027, 0.63], [0.304, 0.037, 0.413], [0.156, 0.044, 0.214]])

histogram_results = np.array([[0.023, 0.12, 0.178], [0.045, 0.085, 0.22], [0.025, 0.101, 0.179], [0.041, 0.064, 0.179], [0.038, 0.07, 0.186], [0.003, 0.056, 0]])

cluster_results = np.array([[0.641, 0.018, 0.78], [0.487, 0.027, 0.63], [0.434, 0.03, 0.571], [0.361, 0.034, 0.485], [0.487, 0.027, 0.63], [0.357, 0.035, 0.598]])

svm_results = np.array([[0.346, 0.035, 0.578], [0.222, 0.041, 0.388], [0.184, 0.062, 0.436], [0.184, 0.06, 0.434], [0.158, 0.068, 0.404], [0.084, 0.077, 0.294]])

isolation_results = np.array([[0.285, 0.069, 0.531], [0.162, 0.096, 0.4], [0.024, 0.119, 0.179], [0.047, 0.17, 0.227], [0.093, 0.242, 0.258], [0.012, 0.13, 0.145]])

results_tpl = np.array([[], [], [], [], [], []])

# %%
scores = [{ 'title' : 'RPCA', 'scores' :  rpca_results }, 
          { 'title' : 'Histogram', 'scores' :  histogram_results }, 
          { 'title' : 'Cluster', 'scores' :  cluster_results }, 
          { 'title' : 'SVM', 'scores' :  svm_results }, 
          { 'title' : 'Isolation Forest', 'scores' :  isolation_results }
         ]

# %%
def generate_nmi_line_chart(dimension, scores):
    fig, ax = plt.subplots()
    
    for score in scores:
        title = score['title']
        results = score['scores']
        ax.plot(dimension, results[:,0], label=title)
    ax.set_ylabel('Score')
    ax.set_xlabel('Number of TS')
    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left", borderaxespad=0, ncol=3)
    
    fig.tight_layout()
    plt.show()

# %%
def generate_rmse_line_chart(dimension, scores):
    fig, ax = plt.subplots()
    
    for score in scores:
        title = score['title']
        results = score['scores']
        ax.plot(dimension, results[:,1], label=title)
        #ax.plot(dimension, scores[:, 1], label='$RMSE$')
        #ax.plot(dimension, scores[:, 2], label='$F_1-Score$')
    ax.set_ylabel('Score')
    ax.set_xlabel('Number of TS')
    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left", borderaxespad=0, ncol=3)
    
    fig.tight_layout()
    plt.show()

# %%
def generate_f1_line_chart(dimension, scores):
    fig, ax = plt.subplots()
    
    for score in scores:
        title = score['title']
        results = score['scores']
        ax.plot(dimension, results[:,2], label=title)
    ax.set_ylabel('Score')
    ax.set_xlabel('Number of TS')
    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left", borderaxespad=0, ncol=3)
    
    fig.tight_layout()
    plt.show()

# %%
generate_nmi_line_chart(dimension, scores)

# %%
generate_rmse_line_chart(dimension, scores)

# %%
generate_f1_line_chart(dimension, scores)

# %%
def autolabel(ax, rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# %%
def generate_plot(dimension, scores):
    #plt.style.use('ggplot')
    #plt.style.use('seaborn-white')
    x = np.arange(len(dimension))  # the label locations
    width = 0.35  # the width of the bars

    fig, ax = plt.subplots()
    ax.grid(axis='y', color='lightgrey', zorder=0)
    rects1 = ax.bar(x - width/2, scores[:, 0], width/2, label='NMI', zorder=2)
    rects2 = ax.bar(x, scores[:, 2], width/2, label='F1-Score', zorder=2)
    rects3 = ax.bar(x + width/2, scores[:, 1], width/2, label='RMSE', zorder=2)

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Score')
    ax.set_xlabel('Number of TS')
    #ax.set_title(title)
    ax.set_xticks(x)
    ax.set_xticklabels(dimension)
    #ax.legend()
    ax.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left", borderaxespad=0, ncol=3)

    #autolabel(ax, rects1)
    #autolabel(ax, rects2)
    #autolabel(ax, rects3)

    fig.tight_layout()

    plt.show()

# %%
generate_plot(dimension, lisa_pearson_results)

# %%
generate_plot(dimension, lisa_dtw_results)

# %%
generate_plot(dimension, lisa_spatial_results)

# %%
generate_plot(dimension, rpca_results)

# %%
generate_plot(dimension, histogram_results)
