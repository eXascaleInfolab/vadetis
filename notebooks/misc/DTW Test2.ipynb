# %%
from lisa.utils import *

# %%
from lisa.library import *

# %%
import lisa.models

# %%
import numpy as np, pandas as pd

# %%
datastream = DataStream.objects.get(id=34)

# %%
df = datastream.dataframe

# %%
df
# Out:
# station               1     2     7     8     9     10    11    12    13   \
# time
# 2017-03-01 00:00:00  -2.7   0.8   1.9  -0.3   1.1   1.1   1.6   0.9  -0.2
# 2017-03-01 01:00:00  -2.8   0.9   1.9  -1.2   1.4   1.1   0.6   0.7   0.3
# 2017-03-01 02:00:00  -2.8   1.3   2.2  -1.1   1.4   1.6   1.8   1.1  -0.1
# 2017-03-01 03:00:00  -2.8   0.8   0.7  -0.1   1.7   1.5   0.9   2.2  -0.7
# 2017-03-01 04:00:00  -2.3   0.8   0.7   0.1   2.3   1.6   0.0   0.9  -0.3
# 2017-03-01 05:00:00  -1.6   1.3   1.6   0.3   2.7   1.5   0.2   0.6   0.4
# 2017-03-01 06:00:00  -1.5   1.5   2.3   0.8   2.5   1.6   0.7   1.2   0.8
# 2017-03-01 07:00:00  -1.3   2.1   2.9   0.9   3.2   3.1   1.4   1.9   1.2
# 2017-03-01 08:00:00  -0.4   3.6   4.5   1.7   4.1   4.4   2.7   3.1   3.1
# 2017-03-01 09:00:00   0.8   5.1   5.0   3.0   5.0   5.6   3.9   5.6  11.4
# 2017-03-01 10:00:00   2.2   6.0   6.1   4.2   7.0   8.4   5.1   7.1  13.0
# 2017-03-01 11:00:00   3.0   5.8   6.2   5.2   7.6   6.2   5.5   7.0  12.7
# ...

# %%
dtw_pearson(df, 199, 'euclidean', window_size=24)
# Out:
# /Users/adrian/Uni/MasterThesis/PythonCode/lisaweb/lisa/library.py:136: RuntimeWarning: invalid value encountered in double_scalars
#   weight = r_numerator / r_denominator
# Execution time for pearson values using dtw: 0:02:05.522904
# station                   1         2         7         8         9    \
# time
# 2017-03-01 00:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 01:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 02:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 03:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 04:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 05:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 06:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 07:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 08:00:00       NaN       NaN       NaN       NaN       NaN
# ...

# %%
dtw_pearson(df, 199, 'euclidean', window_size=24)
# Out:
# /Users/adrian/Uni/MasterThesis/PythonCode/lisaweb/lisa/library.py:136: RuntimeWarning: invalid value encountered in double_scalars
#   weight = r_numerator / r_denominator
# Execution time for pearson values using dtw: 0:01:57.202145
# station                   1         2         7         8         9    \
# time
# 2017-03-01 00:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 01:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 02:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 03:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 04:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 05:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 06:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 07:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 08:00:00       NaN       NaN       NaN       NaN       NaN
# ...

# %%
dtw_pearson(df, 199, 'euclidean', window_size=24)
# Out:
# /Users/adrian/Uni/MasterThesis/PythonCode/lisaweb/lisa/library.py:136: RuntimeWarning: invalid value encountered in double_scalars
#   weight = r_numerator / r_denominator
# Execution time for pearson values using dtw: 0:02:53.268221
# station                   1         2         7         8         9    \
# time
# 2017-03-01 00:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 01:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 02:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 03:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 04:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 05:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 06:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 07:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 08:00:00       NaN       NaN       NaN       NaN       NaN
# ...

# %%
df_corr = df_zscore.rolling(window=2).apply(lambda x: dtw_df(x))
# Out:
# [-1.12115264  0.07474351]
# [ 0.07474351 -0.52320456]
# [-0.52320456  1.56961369]
# [-1.23717915 -0.57735027]
# [-0.57735027  0.41239305]
# [ 0.41239305  1.40213637]
# [ 0.90453403 -0.30151134]
# [-0.30151134 -1.50755672]
# [-1.50755672  0.90453403]
# [-0.53893623 -1.04617033]
# [-1.04617033  1.61680869]
# [ 1.61680869 -0.03170213]

# %%
path
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-e7fa32cb05ba> in <module>()
# ----> 1 path
#
# NameError: name 'path' is not defined

# %%
df
# Out:
#    0  1
# 0  0  1
# 1  2  3
# 2  4  5

# %%
df.shape[0]
# Out:
# 3

# %%
shape[0]
# Out:
# 3

# %%
dtw_pearson(df, 199, 'euclidean', window_size=24)
# Out:
# /usr/local/lib/python3.5/site-packages/scipy/stats/stats.py:3021: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# Execution time for pearson values using dtw: 0:02:01.589040
# station                   1         2         7         8         9    \
# time
# 2017-03-01 00:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 01:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 02:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 03:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 04:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 05:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 06:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 07:00:00       NaN       NaN       NaN       NaN       NaN
# 2017-03-01 08:00:00       NaN       NaN       NaN       NaN       NaN
# ...
