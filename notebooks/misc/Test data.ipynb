# %%
from lisa.utils import *
from lisa.library import *
import lisa.models
import numpy as np, pandas as pd, datetime, pytz

# %%
N=1024
for i in range(N):
    val = np.sin(2*np.pi*i / float(N/12)) + 1
    print(val)
# Out:
# 1.0
# 1.0735645636
# 1.14673047446
# 1.21910124016
# 1.29028467725
# 1.35989503653
# 1.42755509343
# 1.49289819223
# 1.55557023302
# 1.61523159058
# 1.67155895485
# 1.72424708295
# 1.77301045336
# 1.81758481315
# 1.85772861
# 1.8932243012
# 1.92387953251
# 1.94952818059
# 1.97003125319
# 1.98527764239
# 1.99518472667
# 1.9996988187
# 1.99879545621
# 1.9924795346
# 1.9807852804
# 1.9637760658
# 1.94154406518
# 1.9142097557
# 1.88192126435
# 1.84485356525
# 1.80320753148
# 1.75720884651
# 1.70710678119
# 1.65317284295
# 1.59569930449
# 1.53499761989
# 1.47139673683
# 1.405241314
# 1.33688985339
# 1.26671275747
# 1.19509032202
# 1.1224106752
# 1.04906767433
# 0.975458771477
# 0.90198285967
# 0.82903811124
# 0.757019820097
# 0.686318259601
# 0.617316567635
# 0.550388670345
# 0.485897255807
# 0.424191808582
# 0.365606715836
# 0.310459455263
# 0.259048874645
# 0.211653572373
# 0.168530387697
# 0.129913008891
# 0.0960107068766
# 0.0670072011653
# 0.0430596642678
# 0.0242978699615
# ...

# %%
N=2048
i = np.arange(N)
val = np.sin(2*np.pi*i / float(N/12)) + 1

# %%
testdata_sin_csv(datetime.datetime(2017, 4, 1, 0), '/Users/adrian/Uni/MasterThesis/test_data/test_data_sin/test_data_sin.txt', 'sin_test')

# %%
testdata_sin_csv(datetime.datetime(2017, 4, 1, 0), '/Users/adrian/Uni/MasterThesis/IDAWEB/idaweb3/test_data_sin/test_data_sin3.txt', 'sin_test3', a=1.5, a_shift=1.2, b_shift=0.5)

# %%
testdata_staircase_csv(datetime.datetime(2017, 4, 1, 0), '/Users/adrian/Uni/MasterThesis/IDAWEB/idaweb3/test_data_staircase/test_data_staircase.txt', 'stair_test')

# %%
testdata_staircase_csv(datetime.datetime(2017, 4, 1, 0), '/Users/adrian/Uni/MasterThesis/IDAWEB/idaweb3/test_data_staircase/test_data_staircase2.txt', 'stair_test2', offset_value=0)

# %%
testdata_staircase_csv(datetime.datetime(2017, 4, 1, 0), '/Users/adrian/Uni/MasterThesis/IDAWEB/idaweb3/test_data_staircase/test_data_staircase3.txt', 'stair_test3', grow=True)

# %%
testdata_staircase_csv(datetime.datetime(2017, 4, 1, 0), '/Users/adrian/Uni/MasterThesis/IDAWEB/idaweb3/test_data_staircase/test_data_staircase4.txt', 'stair_test4', N_station=12, offset_value=0, horizontal_offset=1)

# %%
testdata_staircase_csv(datetime.datetime(2017, 4, 1, 0), '/Users/adrian/Uni/MasterThesis/IDAWEB/idaweb3/test_data_staircase/test_data_staircase5.txt', 'stair_test5', N_station=12, offset_value=0.5, grow=True, horizontal_offset=1)

# %%
testdata_staircase_csv(datetime.datetime(2017, 4, 1, 0), '/Users/adrian/Uni/MasterThesis/IDAWEB/idaweb3/test_data_staircase/test_data_staircase5v2.txt', 'stair_test5v2', N_station=4, offset_value=0.5, grow=True, horizontal_offset=1)

# %%
testdata_staircase_csv(datetime.datetime(2017, 4, 1, 0), '/Users/adrian/Uni/MasterThesis/IDAWEB/idaweb3/test_data_staircase/test_data_staircase6.txt', 'stair_test6', N_station=50)

# %%
testdata_staircase_csv(datetime.datetime(2017, 4, 1, 0), '/Users/adrian/Uni/MasterThesis/IDAWEB/idaweb3/test_data_staircase/test_data_staircase6_additional.txt', 'stair_test6', N_station=5, start_value=100)

# %%
testdata_staircase_csv(datetime.datetime(2017, 4, 1, 0), '/Users/adrian/Uni/MasterThesis/IDAWEB/idaweb3/test_data_staircase/test_data_staircaseMODTest4.txt', 'stair_testModTest4')

# %%
testdata_sin_csv(datetime.datetime(2017, 4, 1, 0), '/Users/adrian/Uni/MasterThesis/test_data/test_data_sin/test_data_sin.txt', 'sin_test', a_shift=1.5, b_shift=0.5)

# %%
testdata_sin_csv(datetime.datetime(2017, 4, 1, 0), '/Users/adrian/Uni/MasterThesis/test_data/test_data_sin/test_data_sin2.txt', 'sin_test', N=1000, b_shift=0.1)

# %%
testdata_gaussian_csv(datetime.datetime(2017, 7, 1, 0), '/Users/adrian/Uni/MasterThesis/test_data/test_data_gaussian/gaussian_04.txt', N_station=7, N=2000, mean=1, mean_shift=0.1, std=1, std_shift=0, height_shift=0, num_each_anomaly=20, minutes=10, unit='Quantity')

# %%
testdata_sin_csv(datetime.datetime(2017, 4, 1, 0), '/Users/adrian/Uni/MasterThesis/test_data/test_data_sin_with_class/test_data_sin_with_class_train.txt', 'Quantity', 'sin_test', a=1.2, N=1000, b_shift=0.1)
