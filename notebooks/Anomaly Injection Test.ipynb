# %%
from vadetisweb.utils import *
from vadetisweb.models import DataSet

# %%
stochastic_duration(100, 200)
# Out:
# 110

# %%
from random import randrange

# %%
randrange(100, 200)
# Out:
# 183

# %%
dataset = DataSet.objects.get(id=13)

# %%
df = dataset.dataframe
df.iloc[1:10000, :]
# Out:
# ts_name                    53        54        55        56        57  \
# time
# 2017-04-01 01:00:00  1.075327  1.175327  1.275327  1.375327  1.475327
# 2017-04-01 02:00:00  1.150226  1.250226  1.350226  1.450226  1.550226
# 2017-04-01 03:00:00  1.224271  1.324271  1.424271  1.524271  1.624271
# 2017-04-01 04:00:00  1.297042  1.397042  1.497042  1.597042  1.697042
# 2017-04-01 05:00:00  1.368125  1.468125  1.568125  1.668125  1.768125
# ...                       ...       ...       ...       ...       ...
# 2017-05-12 11:00:00  0.631875  0.731875  0.831875  0.931875  1.031875
# 2017-05-12 12:00:00  0.702958  0.802958  0.902958  1.002958  1.102958
# 2017-05-12 13:00:00  0.775729  0.875729  0.975729  1.075729  1.175729
# 2017-05-12 14:00:00  0.849774  0.949774  1.049774  1.149774  1.249774
# 2017-05-12 15:00:00  0.924673  1.024673  1.124673  1.224673  1.324673
#
# ts_name                    58        59        60        61        62
# time
# ...

# %%
len(df.index)
# Out:
# 1000

# %%
import random
print(random.uniform(0, 1))
if random.uniform(0, 1) < 0.1:
    print('aaa')
# Out:
# 0.12723618841283268

# %%
df.iloc[16,:]
# Out:
# ts_name
# 53     1.934329
# 54     2.034329
# 55     2.134329
# 56     2.234329
# 57     2.334329
# 58     2.434329
# 59     2.534329
# 60    20.634329
# 61     2.734329
# 62     2.834329
# Name: 2017-04-01 16:00:00, dtype: float64

# %%
df.iloc[16,:].std(axis=0, skipna=True, level=None, ddof=0)
# Out:
# 5.490218574883882

# %%
from datetime import datetime
df.iloc[100,:].std(axis=1, skipna=True, level=None, ddof=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-23ded553bff4> in <module>
#       1 from datetime import datetime
# ----> 2 df.iloc[100,:].std(axis=1, skipna=True, level=None, ddof=0)
#
# ~/Uni/Vadetis/venv/lib/python3.7/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, ddof, numeric_only, **kwargs)
#   11638             )
#   11639         return self._reduce(
# > 11640             f, name, axis=axis, numeric_only=numeric_only, skipna=skipna, ddof=ddof
#   11641         )
#   11642
#
# ~/Uni/Vadetis/venv/lib/python3.7/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4064
#    4065         if axis is not None:
# -> 4066             self._get_axis_number(axis)
#    4067
#    4068         if isinstance(delegate, Categorical):
#
# ...

# %%
print(df_part.loc[time_series_ids].std(skipna=skipna, level=None, ddof=0)
# Out:
# ts_name                 53     54     55     56     57     58     59     60  \
# time
# 2017-04-01 00:00:00  False  False  False  False  False  False  False  False
# 2017-04-01 01:00:00  False  False  False  False  False  False  False  False
# 2017-04-01 02:00:00  False  False  False  False  False  False  False  False
# 2017-04-01 03:00:00  False  False  False  False  False  False  False  False
# 2017-04-01 04:00:00  False  False  False  False  False  False  False  False
# ...                    ...    ...    ...    ...    ...    ...    ...    ...
# 2017-05-12 11:00:00  False  False  False  False  False  False  False  False
# 2017-05-12 12:00:00  False  False  False  False  False  False  False  False
# 2017-05-12 13:00:00  False  False  False  False  False  False  False  False
# 2017-05-12 14:00:00  False  False  False  False  False  False  False  False
# 2017-05-12 15:00:00  False  False  False  False  False  False  False  False
#
# ts_name                 61     62
# time
# ...
