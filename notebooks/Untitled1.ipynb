# %%
from lisa.utils import *

# %%
from lisa.library import *

# %%
import lisa.models

# %%
import numpy as np, pandas as pd, datetime

# %%
datastream = DataStream.objects.get(id=34)

# %%
df = datastream.dataframe

# %%
df_dist = df_distance(df, "CH1903")

# %%
df_dist
# Out:
# station      1        2        3        4        5        6        7    \
# station
# 1              0  55902.8  19887.6  80906.1  59945.4  31046.9  69741.7
# 2        55902.8        0  41274.9  34844.2  81096.5  47051.1  17843.8
# 3        19887.6  41274.9        0  61842.4  72950.1  37593.4  57591.3
# 4        80906.1  34844.2  61842.4        0   115712  80454.9  41841.7
# 5        59945.4  81096.5  72950.1   115712        0  37190.4  82348.3
# 6        31046.9  47051.1  37593.4  80454.9  37190.4        0  53588.2
# 7        69741.7  17843.8  57591.3  41841.7  82348.3  53588.2        0
# 8          53171  26674.1  47692.3  61020.8  57385.3  30119.3  25105.9
# 9        53729.5  60974.4  61269.2  95815.5  21819.8    23827  60752.6
# 10       57660.3  14272.2    39714  24486.3  92125.2  56217.4  29676.6
# 11       86545.1  38283.2  76624.8  57215.4  86602.9  65094.4    20478
# 12        150051   121906   149710   145190   109918   119319   106155
# ...

# %%
station1 = Station.objects.get(pk=1)

# %%
station2 = Station.objects.get(pk=2)

# %%
linear_distance(station1.ch1903_easting, station1.ch1903_northing, station2.ch1903_easting, station2.ch1903_northing)
# Out:
# 55902.75221310664

# %%
df_corr = df_corr_geo_distance(df_dist)

# %%
df_corr
# Out:
# station       1         2         3         4         5         6         7    \
# station
# 1        0.000000  0.004608  0.001639  0.006669  0.004942  0.002559  0.005749
# 2        0.004599  0.000000  0.003396  0.002866  0.006671  0.003871  0.001468
# 3        0.001602  0.003325  0.000000  0.004981  0.005876  0.003028  0.004639
# 4        0.005525  0.002380  0.004223  0.000000  0.007902  0.005495  0.002858
# 5        0.005626  0.007611  0.006847  0.010860  0.000000  0.003490  0.007729
# 6        0.002875  0.004358  0.003482  0.007451  0.003444  0.000000  0.004963
# 7        0.005785  0.001480  0.004777  0.003471  0.006831  0.004445  0.000000
# 8        0.004862  0.002439  0.004361  0.005580  0.005248  0.002754  0.002296
# 9        0.005205  0.005907  0.005935  0.009282  0.002114  0.002308  0.005885
# 10       0.004458  0.001104  0.003071  0.001893  0.007123  0.004347  0.002295
# 11       0.007105  0.003143  0.006291  0.004697  0.007110  0.005344  0.001681
# ...

# %%
df_distance(df, "CH1903")
# Out:
# station      1        2        3        4        5        6        7    \
# station
# 1              0  55902.8  19887.6  80906.1  59945.4  31046.9  69741.7
# 2        55902.8        0  41274.9  34844.2  81096.5  47051.1  17843.8
# 3        19887.6  41274.9        0  61842.4  72950.1  37593.4  57591.3
# 4        80906.1  34844.2  61842.4        0   115712  80454.9  41841.7
# 5        59945.4  81096.5  72950.1   115712        0  37190.4  82348.3
# 6        31046.9  47051.1  37593.4  80454.9  37190.4        0  53588.2
# 7        69741.7  17843.8  57591.3  41841.7  82348.3  53588.2        0
# 8          53171  26674.1  47692.3  61020.8  57385.3  30119.3  25105.9
# 9        53729.5  60974.4  61269.2  95815.5  21819.8    23827  60752.6
# 10       57660.3  14272.2    39714  24486.3  92125.2  56217.4  29676.6
# 11       86545.1  38283.2  76624.8  57215.4  86602.9  65094.4    20478
# 12        150051   121906   149710   145190   109918   119319   106155
# ...

# %%
df_dist = df_distance(df, "Haversine")

# %%
# %timeit df_corr_geo_distance(df_dist)
# Out:
# 10 loops, best of 3: 100 ms per loop

# %%
df_corr2
# Out:
# station       1         2         3         4         5         6         7    \
# station
# 1        0.000000  0.004504  0.001585  0.006693  0.004905  0.002446  0.005694
# 2        0.004488  0.000000  0.003411  0.002951  0.006667  0.003848  0.001483
# 3        0.001540  0.003328  0.000000  0.005064  0.005872  0.003009  0.004677
# 4        0.005509  0.002439  0.004289  0.000000  0.007935  0.005525  0.002845
# 5        0.005552  0.007573  0.006837  0.010910  0.000000  0.003507  0.007774
# 6        0.002733  0.004314  0.003459  0.007498  0.003461  0.000000  0.005005
# 7        0.005700  0.001490  0.004817  0.003460  0.006876  0.004484  0.000000
# 8        0.004706  0.002373  0.004343  0.005592  0.005274  0.002756  0.002328
# 9        0.005113  0.005830  0.005938  0.009296  0.002182  0.002335  0.005881
# 10       0.004371  0.001091  0.003084  0.001992  0.007116  0.004318  0.002272
# 11       0.007002  0.003140  0.006317  0.004688  0.007143  0.005368  0.001672
# ...

# %%
df_corr.loc[:,1].sum()
# Out:
# 12130933.639630586

# %%
df_corr = df_dist.div(df_dist.sum(axis=1), axis=0)

# %%
df_corr
# Out:
# station         1           2           3            4           5    \
# station
# 1                 0  0.00460828  0.00163941   0.00666941  0.00494153
# 2         0.0045989           0  0.00339553    0.0028665  0.00667149
# 3        0.00160196  0.00332473           0   0.00498145  0.00587618
# 4        0.00552534  0.00237963  0.00422341            0  0.00790234
# 5        0.00562607  0.00761117   0.0068466    0.0108599           0
# 6        0.00287532   0.0043575   0.0034816   0.00745109  0.00344428
# 7        0.00578507  0.00148015   0.0047772   0.00347077  0.00683079
# 8         0.0048622   0.0024392  0.00436121   0.00558003  0.00524757
# 9         0.0052049  0.00590673  0.00593528   0.00928187  0.00211373
# 10       0.00445822  0.00110351  0.00307063   0.00189325    0.007123
# 11       0.00710496  0.00314287  0.00629054   0.00469713   0.0071097
# 12         0.010638   0.0086427   0.0106139    0.0102934  0.00779277
# ...

# %%
df_corr.loc[1,:].sum()
# Out:
# 1.0

# %%
df_corr
# Out:
# station         1           2           3            4           5    \
# station
# 1                 0  0.00460828  0.00163941   0.00666941  0.00494153
# 2         0.0045989           0  0.00339553    0.0028665  0.00667149
# 3        0.00160196  0.00332473           0   0.00498145  0.00587618
# 4        0.00552534  0.00237963  0.00422341            0  0.00790234
# 5        0.00562607  0.00761117   0.0068466    0.0108599           0
# 6        0.00287532   0.0043575   0.0034816   0.00745109  0.00344428
# 7        0.00578507  0.00148015   0.0047772   0.00347077  0.00683079
# 8         0.0048622   0.0024392  0.00436121   0.00558003  0.00524757
# 9         0.0052049  0.00590673  0.00593528   0.00928187  0.00211373
# 10       0.00445822  0.00110351  0.00307063   0.00189325    0.007123
# 11       0.00710496  0.00314287  0.00629054   0.00469713   0.0071097
# 12         0.010638   0.0086427   0.0106139    0.0102934  0.00779277
# ...

# %%
df_weights[np.isinf(df_weights)] = np.nan

# %%
df_weights.loc[1,2:].sum()
# Out:
# 0.0015714128372746878

# %%
df_weights
# Out:
# station       1         2         3         4         5         6         7    \
# station
# 1             NaN  0.000018  0.000050  0.000012  0.000017  0.000032  0.000014
# 2        0.000018       NaN  0.000024  0.000029  0.000012  0.000021  0.000056
# 3        0.000050  0.000024       NaN  0.000016  0.000014  0.000027  0.000017
# 4        0.000012  0.000029  0.000016       NaN  0.000009  0.000012  0.000024
# 5        0.000017  0.000012  0.000014  0.000009       NaN  0.000027  0.000012
# 6        0.000032  0.000021  0.000027  0.000012  0.000027       NaN  0.000019
# 7        0.000014  0.000056  0.000017  0.000024  0.000012  0.000019       NaN
# 8        0.000019  0.000037  0.000021  0.000016  0.000017  0.000033  0.000040
# 9        0.000019  0.000016  0.000016  0.000010  0.000046  0.000042  0.000016
# 10       0.000017  0.000070  0.000025  0.000041  0.000011  0.000018  0.000034
# 11       0.000012  0.000026  0.000013  0.000017  0.000012  0.000015  0.000049
# ...

# %%
df_weights /= df_weights.sum(axis=0)

# %%
df_weights
# Out:
# station       1         2         3         4         5         6         7    \
# station
# 1             NaN  0.011081  0.031716  0.008262  0.009210  0.019165  0.008928
# 2        0.011384       NaN  0.015282  0.019183  0.006808  0.012646  0.034893
# 3        0.031998  0.015007       NaN  0.010809  0.007568  0.015828  0.010811
# 4        0.007866  0.017777  0.010199       NaN  0.004771  0.007396  0.014880
# 5        0.010616  0.007638  0.008646  0.005777       NaN  0.015999  0.007561
# 6        0.020497  0.013165  0.016778  0.008308  0.014845       NaN  0.011619
# 7        0.009125  0.034714  0.010952  0.015975  0.006704  0.011104       NaN
# 8        0.011968  0.023222  0.013225  0.010954  0.009621  0.019756  0.024800
# 9        0.011844  0.010159  0.010295  0.006976  0.025302  0.024973  0.010249
# 10       0.011037  0.043401  0.015882  0.027298  0.005993  0.010584  0.020980
# 11       0.007353  0.016180  0.008232  0.011683  0.006375  0.009141  0.030405
# ...

# %%
df_corr.loc[1,:].sum()
# Out:
# 1.0

# %%
df_dist
# Out:
# station      1        2        3        4        5        6        7    \
# station
# 1              0  55902.8  19887.6  80906.1  59945.4  31046.9  69741.7
# 2        55902.8        0  41274.9  34844.2  81096.5  47051.1  17843.8
# 3        19887.6  41274.9        0  61842.4  72950.1  37593.4  57591.3
# 4        80906.1  34844.2  61842.4        0   115712  80454.9  41841.7
# 5        59945.4  81096.5  72950.1   115712        0  37190.4  82348.3
# 6        31046.9  47051.1  37593.4  80454.9  37190.4        0  53588.2
# 7        69741.7  17843.8  57591.3  41841.7  82348.3  53588.2        0
# 8          53171  26674.1  47692.3  61020.8  57385.3  30119.3  25105.9
# 9        53729.5  60974.4  61269.2  95815.5  21819.8    23827  60752.6
# 10       57660.3  14272.2    39714  24486.3  92125.2  56217.4  29676.6
# 11       86545.1  38283.2  76624.8  57215.4  86602.9  65094.4    20478
# 12        150051   121906   149710   145190   109918   119319   106155
# ...

# %%
df_corrx = 1.0 / df_dist.astype('float64')

# %%
df_corrx[np.isinf(df_corrx)] = np.nan

# %%
df_corrx /= df_corrx.sum(axis=0)

# %%
df_corrx
# Out:
# station       1         2         3         4         5         6         7    \
# station
# 1             NaN  0.011081  0.031716  0.008262  0.009210  0.019165  0.008928
# 2        0.011384       NaN  0.015282  0.019183  0.006808  0.012646  0.034893
# 3        0.031998  0.015007       NaN  0.010809  0.007568  0.015828  0.010811
# 4        0.007866  0.017777  0.010199       NaN  0.004771  0.007396  0.014880
# 5        0.010616  0.007638  0.008646  0.005777       NaN  0.015999  0.007561
# 6        0.020497  0.013165  0.016778  0.008308  0.014845       NaN  0.011619
# 7        0.009125  0.034714  0.010952  0.015975  0.006704  0.011104       NaN
# 8        0.011968  0.023222  0.013225  0.010954  0.009621  0.019756  0.024800
# 9        0.011844  0.010159  0.010295  0.006976  0.025302  0.024973  0.010249
# 10       0.011037  0.043401  0.015882  0.027298  0.005993  0.010584  0.020980
# 11       0.007353  0.016180  0.008232  0.011683  0.006375  0.009141  0.030405
# ...

# %%
df_corr = df_corr_geo_distance(df_dist)

# %%
df_corr.loc[:,1].sum()
# Out:
# 1.0000000000000004

# %%
lisa_calc = LisaCalculation.objects.get(pk=1275)

# %%
lisa_calc.dataframe_lisa
# Out:
#                             1
# time
# 2017-03-01 00:00:00       NaN
# 2017-03-01 01:00:00       NaN
# 2017-03-01 02:00:00       NaN
# 2017-03-01 03:00:00       NaN
# 2017-03-01 04:00:00       NaN
# 2017-03-01 05:00:00       NaN
# 2017-03-01 06:00:00       NaN
# 2017-03-01 07:00:00       NaN
# 2017-03-01 08:00:00       NaN
# 2017-03-01 09:00:00       NaN
# 2017-03-01 10:00:00       NaN
# 2017-03-01 11:00:00       NaN
# 2017-03-01 12:00:00       NaN
# 2017-03-01 13:00:00       NaN
# 2017-03-01 14:00:00       NaN
# 2017-03-01 15:00:00       NaN
# 2017-03-01 16:00:00       NaN
# 2017-03-01 17:00:00       NaN
# 2017-03-01 18:00:00       NaN
# 2017-03-01 19:00:00       NaN
# 2017-03-01 20:00:00       NaN
# 2017-03-01 21:00:00       NaN
# 2017-03-01 22:00:00       NaN
# 2017-03-01 23:00:00       NaN
# 2017-03-02 00:00:00       NaN
# 2017-03-02 01:00:00       NaN
# 2017-03-02 02:00:00       NaN
# 2017-03-02 03:00:00       NaN
# 2017-03-02 04:00:00       NaN
# 2017-03-02 05:00:00       NaN
# ...

# %%
df.index[0]
# Out:
# Timestamp('2017-03-01 00:00:00')

# %%
df
# Out:
# station               1     2     7     8     9     10    11    12    13   \
# time
# 2017-03-01 00:00:00  -2.7   0.8   1.9  -0.3   1.1   1.1   1.6   0.9  -0.2
# 2017-03-01 01:00:00  -2.8   0.9   1.9  -1.2   1.4   1.1   0.6   0.7   0.3
# 2017-03-01 02:00:00  -2.8   1.3   2.2  -1.1   1.4   1.6   1.8   1.1  -0.1
# 2017-03-01 03:00:00  -2.8   0.8   0.7  -0.1   1.7   1.5   0.9   2.2  -0.7
# 2017-03-01 04:00:00  -2.3   0.8   0.7   0.1   2.3   1.6   0.0   0.9  -0.3
# 2017-03-01 05:00:00  -1.6   1.3   1.6   0.3   2.7   1.5   0.2   0.6   0.4
# 2017-03-01 06:00:00  -1.5   1.5   2.3   0.8   2.5   1.6   0.7   1.2   0.8
# 2017-03-01 07:00:00  -1.3   2.1   2.9   0.9   3.2   3.1   1.4   1.9   1.2
# 2017-03-01 08:00:00  -0.4   3.6   4.5   1.7   4.1   4.4   2.7   3.1   3.1
# 2017-03-01 09:00:00   0.8   5.1   5.0   3.0   5.0   5.6   3.9   5.6  11.4
# 2017-03-01 10:00:00   2.2   6.0   6.1   4.2   7.0   8.4   5.1   7.1  13.0
# 2017-03-01 11:00:00   3.0   5.8   6.2   5.2   7.6   6.2   5.5   7.0  12.7
# ...

# %%
df.loc[df.index[0], 2]
# Out:
# 0.80000000000000004

# %%
df_pr = pearson_matrix(df)
# Out:
# Execution time for pearson matrix: 0:00:00.030950

# %%
sorted_pearson = df_pr[1].sort_values(ascending=False)

# %%
num=3

# %%
mostc = sorted_pearson.iloc[1:1000].index.values

# %%
mostc.tolist()
# Out:
# [77,
#  58,
#  74,
#  163,
#  9,
#  66,
#  14,
#  75,
#  110,
#  185,
#  69,
#  84,
#  57,
#  126,
#  8,
#  109,
#  134,
#  47,
#  199,
#  213,
#  80,
#  169,
#  25,
#  206,
#  216,
#  151,
#  53,
#  28,
#  89,
#  71,
#  2,
#  182,
#  158,
#  86,
#  10,
#  177,
#  7,
#  81,
#  16,
#  39,
#  145,
#  198,
#  141,
#  187,
#  11,
#  215,
#  45,
#  117,
#  67,
#  188,
#  217,
#  34,
#  99,
#  12,
#  96,
#  100,
#  98,
#  175,
#  214,
#  93,
#  160,
#  170,
#  164,
#  13,
#  189,
#  92,
#  128,
#  124,
#  183,
#  125,
#  22,
#  19,
#  167]
